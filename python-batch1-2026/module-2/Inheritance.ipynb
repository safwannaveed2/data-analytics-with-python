# %% [markdown]
# # Inheritance

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age  = age

    def greet(self):
        print(f"Hi, I am {self.name}")

    def show_age(self):
        print(f"I am {self.age} years old")


class Teacher:
    def __init__(self, name, age):
        self.name = name           # ← same as Student
        self.age  = age            # ← same as Student

    def greet(self):               # ← same as Student
        print(f"Hi, I am {self.name}")

    def show_age(self):            # ← same as Student
        print(f"I am {self.age} years old")

# %%
# Person  -- Parent Class
#   -- Student -- Child class
#   -- Teacher -- Child class


# Parent Class -- that being inherited
# Child class --  that inherits from parent class (Derived class)

# %%
class Animal:
    def __init__(self, name, sound):
        self.name  = name
        self.sound = sound

    def speak(self):
        return(f"{self.name} says {self.sound}")

    def sleep(self):
        return(f"{self.name} is sleeping...")


# Dog inherits everything from Animal
class Dog(Animal):
    def fetch(self):
        return(f"{self.name} fetches the ball!")

    def wag_tail(self):
        return(f"{self.name} is wagging its tail!")

# %%
d = Dog("Bruno", "Bark")
print(d.sleep())
print(d.fetch())
# Out:
# Bruno is sleeping...
# Bruno fetches the ball!

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age  = age

    def greet(self):
        return (f"Hi, I am {self.name}, {self.age} years old.")


class Student(Person):
    def __init__(self, name, age, student_id):
        # NOT using super() — setting manually
        self.name       = name        # repeat from Person
        self.age        = age         # repeat from Person
        self.student_id = student_id  # new attribute

    def show_id(self):
        return (f"Student ID: {self.student_id}")

    # def greet(self): override - replace parent's version
    #     print(f" {self.name}, {self.age} years old.")

# %%
s1 = Student("Ayan",12,"S01")

print(s1.greet())
print(s1.show_id())
# Out:
# Hi, I am Ayan, 12 years old.
# Student ID: S01

# %%
a = Person("Ayan",12)
print(a.greet())

print(a.show_id())
# Out:
# Hi, I am Ayan, 12 years old.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 4
#       1 a = Person("Ayan",12)
#       2 print(a.greet())
# ----> 4 print(a.show_id())
#
# AttributeError: 'Person' object has no attribute 'show_id'

# %%
class Vehicle:
    def __init__(self, brand, speed):
        self.brand = brand
        self.speed = speed

    def info(self):
        print(f"{self.brand} — {self.speed} km/h")


# WITHOUT super() — duplicate code
class Car(Vehicle):
    def __init__(self, brand, speed, doors):
        self.brand = brand    # copy from Vehicle
        self.speed = speed    # copy from Vehicle
        self.doors = doors


# WITH super() — clean, no duplication
class Car(Vehicle):
    def __init__(self, brand, speed, doors):
        super().__init__(brand, speed)   # Vehicle handles brand & speed
        self.doors = doors               # Car only adds what's new

# WITH super() — clean, no duplication
class Truck(Vehicle):
    def __init__(self, brand, speed, tires):
        super().__init__(brand, speed)   # Vehicle handles brand & speed
        self.tires = tires               # Car only adds what's new

# %% [markdown]
# ## Single Inheritance

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Multiple 

# Kid (father, mother)


# Multiple Level 

# Grandfather ---->  Father ----> Child
