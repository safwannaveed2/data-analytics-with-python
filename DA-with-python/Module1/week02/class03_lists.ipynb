# %%
cities = ["Karachi", "Lahore", "Islamabad", "Peshawar"]

numbers = [1,2,3,4,5,6,7]  # indices:  0,1,2,3,4,5,6
print(numbers[1])   # index 1 -> second element
print(len(numbers)) # total number of elements in the list

cities = ["Karachi", "Lahore", "Islamabad", "Peshawar"]
print(cities[10]) # index error
# Out:
# 2
# 7
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 8
#       5 print(len(numbers)) # total number of elements in the list
#       7 cities = ["Karachi", "Lahore", "Islamabad", "Peshawar"]
# ----> 8 print(cities[10])
#
# IndexError: list index out of range

# %%
cities = ["Karachi", "Lahore", "Islamabad", "Peshawar"]
#            -4          -3          -2          -1     <- negative indices, counted from the end

# Negative indexing starts at -1 for the last element and counts backwards
# print(cities[3])

print(cities[-1])  # last element -> "Peshawar"
print(cities[-3])  # third from the end -> "Lahore"

# %%
# Wrong approach to add an element: recreating the whole list from scratch
# instead of using a list method like append()

saylani_campuses = ['Z.A', 'Headoffice','Ibne-Adam']
print(saylani_campuses)
saylani_campuses = ['Z.A', 'Headoffice','Ibne-Adam', 'quetta-campus']  # had to retype every item just to add one
print(saylani_campuses)

# %% [markdown]
# # Append

# %%
# append() adds a single value to the end of the list, in place

saylani_campuses = ['Z.A', 'Headoffice','Ibne-Adam']
saylani_campuses.append('Quetta-campus')  # adds one value at a time

print(saylani_campuses)

saylani_campuses.append('Naya-nazimabda-campus')
print(saylani_campuses)

# %% [markdown]
# # Pop

# %%
saylani_campuses.pop()  # removes and returns the last element (index -1)
print(saylani_campuses)

# removed: 'Quetta-campus' (was at index 3)

# %%
saylani_campuses.pop(2)  # removes and returns the element at index 2 ('Ibne-Adam')
print(saylani_campuses)

# removed: 'Ibne-Adam' (was at index 2)

# %%
print(saylani_campuses)
print(saylani_campuses.index('Quetta-campus'))
# Out:
# ['Z.A', 'Headoffice', 'Quetta-campus']
# 2

# %%
len(saylani_campuses)
# Out:
# 3

# %% [markdown]
# # Insert

# %%
saylani_campuses = ['Z.A', 'Headoffice','Ibne-Adam']
# insert(index, value) -- inserts value at the given index, shifting later elements right

saylani_campuses.insert(0,"Malir-campus")

# %%
print(saylani_campuses)
# Out:
# ['Malir-campus', 'Z.A', 'Headoffice', 'Ibne-Adam']

# %%
print(saylani_campuses.index('Z.A'))
# Out:
# 1

# %%
saylani_campuses.insert(2,"lahore-campus") 
print(saylani_campuses)
# Out:
# ['Malir-campus', 'Z.A', 'lahore-campus', 'Headoffice', 'Ibne-Adam']

# %%
print(saylani_campuses[3])
# Out:
# Headoffice

# %%
print(saylani_campuses.index('Headoffice'))
# Out:
# 3

# %% [markdown]
# # remove

# %%
saylani_campuses = ['Malir-campus', 'Z.A', 'lahore-campus', 'Headoffice', 'Ibne-Adam','Z.A']
# saylani_campuses.pop(1)

saylani_campuses.remove('Z.A')  # removes the first matching value (by value, not by index)
print(saylani_campuses)

# %%
saylani_campuses.remove('Z.A')  # again removes only the first remaining match
print(saylani_campuses)

# %%
# extend() -- HW: adds all elements from another list (unlike append(), which adds a single item/list as one element)

# %%
saylani_campuses = ['Malir-campus', 'Z.A', 'lahore-campus', 'Headoffice', 'Ibne-Adam','Z.A']
saylani_campuses[1] = 'Zaitoon Ashraf IT Park'  # lists are mutable -- direct index assignment works
print(saylani_campuses)

# %% [markdown]
# # Tuples

# %%
saylani_campuses = ('Malir-campus', 'Z.A', 'lahore-campus', 'Headoffice', 'Ibne-Adam')
saylani_campuses[1] = 'Zaitoon Ashraf IT Park'  # tuples are immutable -- this raises TypeError
print(saylani_campuses)
print(type(saylani_campuses))

# %%
# 14.4 — Create a list of five scores. Print the highest (use max()), lowest (use min()), and the total (use sum()). Then append one more score and print the new average.

marks = [80,65,75,55,90,47]
max(marks)
# Out:
# 90

# %%
min(marks)
# Out:
# 47

# %%
sum(marks)
# Out:
# 412

# %%
# Nested list 

matrix = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]

# matrix
# index 0  [1,2,3]
# index 1 [4,5,6]
# index 2 [7,8,9]

print(matrix[0])
print(matrix[1])
print(matrix[2])
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]

# %%
print(matrix[0][1])
print(matrix[0][2])


# listtt = matrix[0]
# print(listtt[1])
# Out:
# 2
# 3

# %%
print(matrix[1][1])
# Out:
# 5

# %%
print(matrix[2][2])
# Out:
# 9
