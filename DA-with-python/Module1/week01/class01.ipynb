# %%
print("Hello World")
# Out:
# Hello World

# %%
key = "hello Sit"
print(key)
# Out:
# hello Sit

# %%
print(10)
# Out:
# 10

# %%
print("Hamza Imran")
# Out:
# Hamza Imran

# %%
print(12345
# Out:
#   Cell In[9], line 1
#     print(12345
#                ^
# _IncompleteInputError: incomplete input

# %%
print(Hamza Imran)
# Out:
#   Cell In[10], line 1
#     print(Hamza Imran)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### Variable

# %%
# -- comments oiajoiuwehgr93wh

# Container that stores a data 

city = 'Karachi' # variable name -- karachi is variable value 
age = 20

# %%
print(city)
# Out:
# karachi

# %%
print(age)
# Out:
# 20

# %%
age = 20 
print(age)
# Out:
# 20

# %%
age = 35
print(age)
# Out:
# 35

# %%
print(age)
# Out:
# 20

# %%
age_student1 = 20
age_student2 = 35

print(age_student1)
print(age_student2)
# Out:
# 20
# 35

# %%
x = 500 
y = 0.17

# z = x * y
print(x * y)
# Out:
# 85.0

# %%
bill = 500
tax_rate = 0.15
tax_amount = bill * tax_rate
print(tax_amount)

total_bill = bill + tax_amount
print(total_bill)
# Out:
# 75.0
# 575.0

# %% [markdown]
# ## Data Types

# %%
# 1 - Int 12,10
# 2 - Float 0.5 , 15.5
# 3 - Str  "Hello" "Ayan"
# 4 - boolean True/False

# %%
is_sunday = False
print(is_sunday)
# Out:
# False

# %%
is_saturday = True
print(is_saturday)
# Out:
# True

# %%
# type 

value = 5000
print(type(value))
# Out:
# <class 'int'>

# %%
value = 5000.025
print(type(value))
# Out:
# <class 'float'>

# %%
name = "Ayan"
print(type(name))
# Out:
# <class 'str'>

# %%
is_saturday = True
print(type(is_saturday))
# Out:
# <class 'bool'>

# %%
first = "Data"
second = "Engineer"

role = first + " " + second
print(role)
# print(first, second)

# print("Data Engineer")
# print("Data","Engineer")
# Out:
# Data Engineer

# %%
print(5+10) # abc + hh -> abchh
# Out:
# 15

# %%
# > < 

files_processed = 47
target = 50
target_met = files_processed > target

print(target_met)
print(type(target_met))
# Out:
# False
# <class 'bool'>

# %%
ans = 10.5 

# int()

ans = int(ans)
print(ans)
print(type(ans))
# Out:
# 10
# <class 'int'>

# %%
age = 10 

# float
age = float(age)
print(age)
print(type(age))
# Out:
# 10.0
# <class 'float'>

# %%
number = "100"
print(type(number)) 

number = int(number)
print(type(number))
# Out:
# <class 'str'>
# <class 'int'>

# %%
name = "Ayan"
print(type(name))

name = int(name)
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 4
#       1 name = "Ayan"
#       2 print(type(name))
# ----> 4 name = int(name)
#
# ValueError: invalid literal for int() with base 10: 'Ayan'
